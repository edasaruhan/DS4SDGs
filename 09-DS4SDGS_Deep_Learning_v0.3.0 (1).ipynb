# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/SDG-AI-Lab/DS4SDGs/blob/summer2023_ch_01/notebooks/09_DS4SDGS_Deep_Learning_v0_3_0.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # **Chapter 9: Deep Learning**
#
#
# ---
# **Introduction:** This chapter sheds light on the introduction of Deep Learning topics and its relevant tasks.
#
# ## **Objectives:**
#
# * To understand the essentials of Deep Learning and Neural Networks
#
# * To familiarize with various terms under Deep Learning
#
# * To understand usage of neural networks on classification problem
#
# ## **Learning Outcomes:**
#
# The learners are expected to have the ability to:
#
# * Gain a good level of understanding on Deep Learning and Neural Networks
#
# * Use Neural Networks for a classification problem
#
# ---

# %% [markdown]
# # **1 Introduction to Deep Learning and Neural Networks**
#
# ![aimldl](https://ichi.pro/assets/images/max/724/0*DTXj4uIfDmtDyL0z)

# %% [markdown]
# ## **1.1 What is Deep Learning?**
#
# Deep Learning is a subset of Machine Learning which has advanced solutions to most complex problems.
#
# The primary goal of deep learning is to enable machines to learn from data so that they can perform tasks that would normally require human intelligence. These tasks include but are not limited to image and speech recognition, natural language understanding, and game playing.
#
#
# Deep Learning is inspired by the structure of a human brain. Deep learning algorithms attempt to draw similar conclusions as humans would by continually analyzing data with a given logical structure. To achieve this, deep learning uses a multi-layered structure of algorithms called **neural networks**.
#
# <br>
#
# ![dl2](https://fromthegenesis.com/wp-content/uploads/2018/06/NNN2.png)
#
# <br>
# Deep learning has been at the forefront of all recent advances in artificial intelligence.

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What is deep learning?
#
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/bef407b2-95db-486f-bdfe-e6b211f6df6e)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/4071aff5d21e)

# %% [markdown]
# ### **1.1.1 Applications of Deep learning**
# Deep learning has found extensive applications across various industries and domains.
#
# Here are some prominent real-world applications:
#
# * **Image Recognition:** Used in facial recognition systems, medical imaging diagnostics, and satellite image analysis.
#
# * **Natural Language Processing (NLP):**
#
#  * *Sentiment Analysis:* Determining the sentiment of a user from their written text.
#  * *Machine Translation:* Translating one language to another, as seen in tools like Google Translate.
#  * *Speech Recognition:* Converting spoken language into text, used in virtual assistants like Siri, Alexa, and Google Assistant.
#
# * **Autonomous Vehicles:** Deep learning powers the vision systems and decision-making capabilities in self-driving cars.
#
# * **Recommendation Systems:** Platforms like Netflix, Spotify, and Amazon use deep learning to analyze user preferences and offer personalized content or product recommendations.
#
# * **Video Analysis:**
#
#  * *Activity Recognition:* Identifying specific activities in video streams, used in surveillance and sports analytics.
#  * *Anomaly Detection:* Identifying unusual patterns in videos, useful for security and quality control.
#
# * **Game Playing:** Deep learning models, like AlphaGo by DeepMind, have achieved superhuman performance in complex games like Go.
#
# * **Voice Assistants:** Improving the naturalness and responsiveness of voice assistants through deep learning-based natural language understanding and synthesis.
#
# * **Financial Forecasting:** Analyzing market conditions and predicting stock prices or potential financial downturns.
#
# * **Healthcare:**
#
#  * *Drug Discovery:* Predicting the potential efficacy of new drugs.
#  * *Disease Identification and Prognosis:* Analyzing medical images or genetic data to identify or predict disease trajectories.
#
# * **Agriculture:** Analyzing crop images to detect diseases or pest infestations and predicting crop yields.

# %% [markdown]
# #### **⚠️ Note:**
#
# The above list is just the tip of the iceberg. The versatility of deep learning ensures its application in many emerging areas, as technology and data availability continue to grow.

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What are some real-world applications of deep learning?
#
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/5a3a7c59-9e20-41ed-9517-93d4fc7e4e18)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/2b1d29f4f806)

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# Copy and past the prompt below in your [ChatGPT](https://chat.openai.com/) and [BARD](https://bard.google.com/) interface.
#
# **Prompt:**
#
# ```
# What is the main difference between deep learning and classical machine learning, especially with regards to the absence of manual feature engineering in deep learning?
#
# ```

# %% [markdown]
# ## **1.2. Neural Networks(NN)**
#
# Just as the human brain identifies patterns and classifies different types of information, neural networks also achieve the same task.
#
# A neural network is made of **layers** and each layer consists of small individual units called **neurons**, as seen the image below.
#
#
#
# The individual layers of neural networks can also be thought of as a sort of filter that works from gross to subtle, increasing the likelihood of detecting and outputting a correct result.
#
# ![dl](https://miro.medium.com/max/875/0*AONVmd3v4wO_dWr6)
#
#
# Neural networks enable us to perform many tasks, such as clustering, classification or regression since it is a subset of Machine Learning

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What is artificial neural networks in deep learning?
#
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/5ff0a57d-d0ee-464c-b7dc-c603c8126c5f)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/4583e84c4d2b)

# %% [markdown]
# ### **1.2.1 Typical Neural Network Architecture:**
#
# The typical neural network architecture consists of several layers.
#
# #### **1.2.1 Input Layer**
#
# The input layer is the initial layer through which the neural network receives its input X, which represents the data from which it learns.
#
# The number of neurons (nodes) in this layer is typically equal to the number of features in the input data, X.
#
# Ideally, each input neuron represents one element in the vector x.
#
# Basically, the input layer  prepares the data for further processing by the subsequent layers.
#
# #### **1.2.2 Output Layer**
#
# This is last layer of neural network which outputs a vector y representing the result that the neural network came up with. The entries in this vector represent the values of the neurons in the output layer. Each neuron in the last layer would represent a different class.
#
#  For instance, for a binary classification problem, you might have one output neuron, while for a multi-class classification problem, you might have as many neurons as there are classes.
#
#
# #### **1.2.3 Hidden Layer**
#
# In order to obtain a prediction vector y, the network must perform certain mathematical operations. These operations are performed in the layers between the input and output layers which called **Hidden Layers**.
#
# These layers, aptly named because they are not directly observed from the input or output data, are pivotal in enabling deep learning models to represent and learn complex functions.
#
# ### 💡 Fun Fact
# The **"deep"** in deep learning or deep neural network usually refers to the multiple hidden layers found in the neural networks.
#
# There are several types of hidden layers including: Dense (fully connected), convolutional layers, recurrent layer, normalization layer, etc.
#
# * **1. Dense (Fully Connected) Layers:** These are the most common type where every neuron in the layer is connected to every neuron in the subsequent layer. The dense layer is a linear operation, but when combined with a non-linear activation function, it provides the network the capability to learn from the error and make adjustments, which is essential for learning complex patterns.
#
# * **2. Convolutional Layers:** Primarily used in convolutional neural networks (CNNs), these layers are specifically designed to recognize spatial hierarchies in data, making them excellent for image recognition tasks. They work by sliding small windows (or kernels) over the input data to produce feature maps, capturing local patterns.
#
# * **3. Recurrent Layers:** Found in recurrent neural networks (RNNs), these layers have loops that allow information to be passed from one step of the network to the next. This architecture is particularly beneficial for tasks where temporal dynamics and sequence recognition are crucial, like in natural language processing or time series prediction.
#
# * **4. Normalization Layers:** These layers, such as Batch Normalization, adjust and scale the activations. By normalizing the layer's inputs, they can help maintain a stable mean and variance, improving the overall training speed and performance of deep networks by mitigating the problem of internal covariate shift.

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# Can you describe the different layers of an artificial neural network?
#
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/b44abf17-7374-4601-ba4a-3c156d777043)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/ef80bf3d91a9)

# %% [markdown]
# ## **1.2.2 Layer Connections:**
#
# The figure below shows a simple neural network that consists only of the input and output layer with 2 input neurons and 3 output neurons:
#
# ![dl5](https://miro.medium.com/max/436/1*U6tiIuizR8PMkrOuqyH5vg.png)
#
# Each connection between two neurons is represented by a numerical value, which called **weight(w)**. Each of these weight w has indices. The first value of the indices stands for the number of neurons in the layer from which the connection originates, the second value for the number of the neurons in the layer to which the connection leads.
#
# All weights between two neural network layers can be represented by a matrix called the **weight matrix**.
#
# ![dl6](https://miro.medium.com/proxy/0*ebwG9bWKzhgZ0OLW)
#
# A weight matrix has the same number of entries as there are connections between neurons. The dimensions of a weight matrix result from the sizes of the two layers that are connected by this weight matrix.
#
# The number of rows corresponds to the number of neurons in the layer from which the connections originate and the number of columns corresponds to the number of neurons in the layer to which the connections lead.
#
# In this particular example, the number of rows of the weight matrix corresponds to the size of the input layer which is two and the number of columns to the size of the output layer which is three.

# %% [markdown]
# ### **1.2.3 Learning Process of a Neural Network:**
#
# For a given input feature vector x, the neural network calculates a prediction vector, which we call here as h.
#
# This step is also referred to as the forward propagation. With the input vector x and the weight matrix W connecting the two neural layers, we compute the dot product between the vector x and the matrix W.
# The result of this dot product is again a vector, which is called z.
#
# ![dl6](https://miro.medium.com/proxy/0*LYoM4KMv_Y46Ko2c)
#
# The final prediction vector h is obtained by applying a so-called activation function to the vector z. In this case, the activation function is represented by the letter Sigma.
#
# ### 💡 **Activation Function**
#
# An **activation function** is only a nonlinear function that performs a nonlinear mapping from z to h.
#
# It allows the network to capture and represent complex relationships in the data.
#
# Activation function is used to determine the output of neural network like yes or no. It maps the resulting values in between 0 to 1 or -1 to 1 etc. (depending upon the function)
#
# There are a couple activation functions that are used in Deep Learning, which include:
#
# 1. tanh
# 2. sigmoid
# 3. Relu

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [Activation Functions: RELU, Tanh, Sigmoid](https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.researchgate.net%2Ffigure%2FActivation-Functions-ReLU-Tanh-Sigmoid_fig4_327435257&psig=AOvVaw0kQJrn_qIf9ePLaH9qIlbO&ust=1695462002614000&source=images&cd=vfe&opi=89978449&ved=0CBIQjhxqFwoTCMDRy6T2vYEDFQAAAAAdAAAAABAE)

# %% [markdown]
# Let us take a closer look at vector z for a moment. Each element of z consists of the input vector x.
#
# At this point, the role of the weights unfolds well. A value of a neuron in a layer consists of a linear combination of neuron values of the previous layer weighted by some numeric values.
#
# *These numerical values are the weights that tell us how strongly these neurons are connected with each other.*
#
# During training, these weights are adjusted, some neurons become more connected, some neurons become less connected. As in a biological neural network, learning means the alteration of weights. Accordingly, the values of z, h and the final output vector y are changing with the weights. Some weights make the predictions of a neural network closer to the actual ground truth vector y_hat, some weights increase the distance to the ground truth vector.
#
# Now that we know how the mathematical calculations between two neural network layers look like, we can extend our knowledge to a deeper architecture that consists of 5 layers.
#
# ![dl7](https://miro.medium.com/proxy/0*nZR65jmWsj97qvFK)
#
# Same as before we calculate the dot product between the input x and the first weight matrix W1 and apply an activation function to the resulting vector to obtain the first hidden vector h1. h1 is now considered as the input for the upcoming third layer. The whole procedure from before is repeated until we obtain the final output y:
#
# ![dl8](https://miro.medium.com/proxy/0*LrkPxaZxvdyOp9OY)
#
#
# After we get the prediction of the neural network, in the second step we must compare this prediction vector to the actual ground truth label. We call the ground truth label as vector y_hat.
#
# While the vector y contains the predictions that the neural network has computed during the forward propagation (and which may, in fact, be very different from the actual values), the vector y_hat contains the actual values.
#
# Mathematically, we can measure the difference between y and y_hat by defining a loss function which value depends on this difference.

# %% [markdown]
# ### **1.2.4 Loss Function:**
#
# A loss function evaluates the difference between the neural networks predicted output (y) and the actual target values (y_hat).
#
#
# Minimizing the loss function automatically causes the neural network model to make better predictions regardless of the exact characteristics of the task at hand.
#
#
# You only have to select the right loss function for the task. Fortunately, there are only two loss functions that you should know (atleast for now) about to solve almost any problem that you encounter in practice.
#
# Let's examine them below:
#
#
# **1. Mean Squared Error (MSE) Loss**
#
# Mean square error (MSE) also known as quadratic loss is typical used when solving regression problems. and it is defined as shown below.
#
# ![d11](https://miro.medium.com/max/875/0*hqIyWVt4QT9ocLf9)
#
# The value of this loss function depends on the difference between y_hat and y.
#
# A higher difference means a higher loss value, a smaller difference means a smaller loss value.
#
# **Minimizing the loss function directly leads to more accurate** predictions of the neural network, as the difference between the prediction and the label decreases.
#
#
#
# **2. Cross Entropy**
#
# Cross entropy loss function is generally used when solving classification problems (binary and multi-class) classification problems.
#
# ![d10](https://miro.medium.com/max/875/0*MukqIvaRuVwLI0Xg)
#
#
#
# Since the loss depends on the weights, we must find a certain set of weights for which the value of the loss function is as small as possible. The method of minimizing the loss function is achieved mathematically by a method called **gradient descent**

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# What are the common lost functions used when training neural networks?
#
# ```
# * [ChatGPT Tutor Response](https://chat.openai.com/share/74f69543-79af-4dbd-a063-f97e16a51814)
#
#
# * [Bard Tutor Response](https://g.co/bard/share/44ca0f84a75d)

# %% [markdown]
# ### **1.2.5 Gradient Descent:**
#
# During gradient descent, we use the gradient of a loss function (or in other words the derivative of the loss function) to improve the weights of a neural network.
#
# To understand the basic concept of the gradient descent process, let us consider a very basic example of a neural network consisting of only one input and one output neuron connected by a weight value w.
#
# ![d12](https://miro.medium.com/max/406/0*3dbe_VC4_XMvbM6R)
#
# This neural network receives an input x and outputs a prediction y. Let say the initial weight value of this neural network is 5 and the input x is 2. Therefore the prediction y of this network has a value of 10, while the label y_hat might have a value of 6.
#
# ![d12](https://miro.medium.com/max/678/0*mXtZkpHtu5qeg83q)
#
# This means that the prediction is not accurate and we must use the gradient descent method to find a new weight value that causes the neural network to make the correct prediction. In the first step, we must choose a loss function for the task. Let’s take the quadratic loss that I have defined earlier and plot this function, which basically is just a quadratic function:
#
# ![dl13](https://miro.medium.com/max/646/0*7NmAQx8Ra5T6qMHw)
#
# The y-axis is the loss value which depends on the difference between the label and the prediction, and thus the network parameters, in this case, the one weight w. The x-axis represents the values for this weight. As you can see there is a certain weight w for which the loss function reaches a global minimum. This value is the optimal weight parameter that would cause the neural network to make the correct prediction which is 6. In this case, the value for the optimal weight would be 3:
#
# ![dl14](https://miro.medium.com/max/623/0*V9GQHcfvXPT1AkIa)
#
# Our initial weight, on the other hand, is 5, which leads to a fairly high loss. The goal now is to repeatedly update the weight parameter until we reach the optimal value for that particular weight. This is the time when we need to use the gradient of the loss function. Fortunately, in this case, the loss function is a function of one single variable, which is the weight w:
#
# ![dl15](https://miro.medium.com/max/875/0*tjuNRPwqCFgw1UfH)
#
# In the next step, we calculate the derivative of the loss function with respect to this parameter:
#
# ![dl16](https://miro.medium.com/max/875/0*xotxCJ9c-DAiuy2S)
#
# In the end, we get a result of 8, which gives us the value of the slope or the tangent of the loss function for the corresponding point on the x-axis at which our initial weight lies.
#
# This tangent points towards the highest rate of increase of the loss function and the corresponding weight parameters on the x-axis.
#
# This means that we have just used the gradient of the loss function to find out which weight parameters would result in an even higher loss value. But what we want to know is the exact opposite. We can get what we want, if we multiply the gradient by minus 1 and this way obtain the opposite direction of the gradient. This way we get the direction of the highest rate of decrease of the loss function and the corresponding parameters on the x-axis that cause this decrease:
#
# ![dl17](https://miro.medium.com/max/616/0*usoWIJDusyugN14x)
#
# In the final step, we perform one gradient descent step as an attempt to improve our weights. We use this negative gradient to update our current weight in the direction of the weights for which the value of the loss function decreases according to the negative gradient:
#
# ![dl17](https://miro.medium.com/max/793/0*GiKZ_TkZ0IBDAt0q)
#
# The factor epsilon in this equation is a hyperparameter called the **learning rate**. The learning rate determines how quickly or how slowly you want to update the parameters. Please keep in mind that the learning rate is the factor with which we have to multiply the negative gradient and that the learning rate is usually quite small. In our case, the learning rate is 0.1.
#
# As you can see, our weight w after the gradient descent is now 4.2 and closer to the optimal weight than it was before the gradient step.
#
# ![dl17](https://miro.medium.com/max/629/0*9jesZe29NhiUlJyg)
#
# The value of the loss function for the new weight value is also smaller, which means that the neural network is now capable to do a better prediction. You can do the calculation in your head and see that the new prediction is, in fact, closer to the label than before.
#
# Each time we are performing the update of the weights, we move down the negative gradient towards the optimal weights.
#
# After each gradient descent step or weight update, the current weights of the network get closer and closer to the optimal weights until we eventually reach them and the neural network will be capable to do the predictions we want to make.

# %% [markdown]
# ### **⚠️ Note:  Variants of the Gradient Descent Algorithm.**
# By minimizing the loss, gradient helps in adjusting the wights of the neural network to improve its performance. The fundamental idea behind gradient descent is to adjust the weights in the direction of the steepest decrease in the lost function. This "direction" is given by the negative gradient of the loss with respect to the weights.
#
# There are several variants of the Gradient Descent Algorithm. Let's examine the most common types:
#
# **1. Batch Gradient Descent**
#
# Batch Gradient Descent uses the entire dataset to compute the gradient of the loss function and update the model's weights in one step.
#
# * **Pros:**
#  * Stable convergence.
#  * Benefits from vectorized operations.
# * **Cons:**
#  * Can be very slow for large datasets.
#  * Memory-intensive with large datasets.
#
# **2. Stochastic Gradient Descent (SGD):**
#
# Updates the model's weights using only one training example at a time.
# * **Pros:**
#  * Faster weight updates.
# Can escape local minima due to noisy updates.
# * **Cons:**
#  * Much noisier updates, leading to oscillations.
#  * Typically requires more epochs to converge.
#
# **3. Mini-Batch Gradient Descent:**
# A compromise between Batch and SGD. Uses a mini-batch (subset) of training examples for each update.
#
# * **Pros:**
#  * Faster than batch gradient descent for large datasets.
#  * Can benefit from hardware optimizations.
# * **Cons:**
#  * Still can have noisy updates (though less than pure SGD).
#  * Mini-batch size requires tuning.
#
#  ### **More Advanced variants of Gradient Algorithm**
#
# **4. Momentum Gradient Descent**
#  Incorporates a velocity term, which is a fraction of the previous update, to determine the next update.
# * **Pros:**
#  * Accelerates convergence.
#  * Reduces oscillations.
# * **Cons:**
#  * Introduces an additional hyperparameter.
#
# **5. Adagrad**
# Adapts the learning rate for each parameter based on the historical gradient information.
# * **Pros:**
#  * Less sensitive to initial learning rate.
#  * Can handle sparse data.
# * **Cons:**
#  * The learning rate can decay too aggressively and become very small.
#
# **6. RMSprop**
# Modifies Adagrad by computing a moving average of squared gradients to adjust the learning rate.
# * **Pros:**
#  * Overcomes Adagrad's aggressive decay.
# * **Cons:**
#  * Introduces another hyperparameter.
#
# **7. Adam (Adaptive Moment Estimation)**
# Combines Momentum and RMSprop. Keeps moving averages of both gradients and squared gradients.
# * **Pros:**
#  * Typically works well in practice with little tuning.
# * **Cons:**
#  * Might be sensitive to hyperparameters in some scenario

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# * Copy and paste the prompt above in your [ChatGPT](https://chat.openai.com/) interface to see the response of ChatGPT machine tutor.
#
# **Prompt:**
#
# ```
# Can you explain in detail the gradient descent algorithm used to update the weights of a neural network?
#
# ```
#
# * [Bard Tutor Response](https://g.co/bard/share/441d6094a5e2)

# %% [markdown]
# ### **1.2.6 Curse of Dimensionality:**
#
# Before we build a neural network, let's mention a critical concept known as Curse of Dimensionality.
#
# Curse of Dimensionality describes the explosive nature of increasing data dimensions and its resulting exponential increase in computational efforts required for its processing and/or analysis. This term was coined by Richard Bellman in the 1960s.
#
#  In the context of deep learning and neural networks, the curse of dimensionality can manifest in several ways:
#
#  * **Data Sparsity:** In high-dimensional spaces, data can become sparse. This means that to get representative samples of all possible combinations of features, you need an exponentially increasing amount of data. For instance, if 10 samples provide a good representation of a single feature, you'd need 100 samples for two features, 1,000 for three features, and so on.
#
# * **Distance Measures Lose Meaning:** In high dimensions, the distance between most pairs of points tends to be very similar, which can be problematic for clustering or nearest neighbor searches.
#
# * **Overfitting:** High-dimensional datasets increase the risk of overfitting, especially if you have a limited amount of data. This is because in higher dimensions, there's a higher likelihood that your model will fit to the noise in the training data rather than the actual underlying pattern.
#
# * **Computational Complexity:** Many algorithms that work fine in low dimensions become intractable as the dimensionality increases.
#
# Hughes (1968) in his study concluded that with a fixed number of training samples, the predictive power of any classifier first increases as the number of dimensions increase, but after a certain value of number of dimensions, the performance deteriorates. Thus, the phenomenon of curse of dimensionality is also known as Hughes phenomenon.

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# [Representation of Hughes Principle](https://towardsdatascience.com/curse-of-dimensionality-a-curse-to-machine-learning-c122ee33bfeb)

# %% [markdown]
# **Methods to Handle the Curse of Dimensionality in Deep Neural Networks:**
#
#  The methods to handle the curse of dimensionality include but not limited to the following:
#
# * **Dimensionality Reduction**: Techniques like PCA (Principal Component Analysis), t-SNE, and autoencoders can be used to reduce the number of features in the data without losing much information.
#
# * **Regularization**: Techniques such as L1 and L2 regularization can help prevent overfitting by adding penalty terms to the loss function, which in turn constrain the weights of the model. Dropout is another regularization technique often used in deep neural networks which randomly deactivates a fraction of neurons during training.
#
# * **Feature Engineering**: Manually or algorithmically selecting the most important features or transforming features into a more useful representation can reduce dimensionality.
#
# * **Feature Extraction**: Deep learning itself can be used as a form of feature extraction. For instance, convolutional neural networks (CNNs) are adept at this, transforming raw image data into a hierarchical set of features.

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# * Copy and paste the prompt above in your [ChatGPT](https://chat.openai.com/) interface to see the response of ChatGPT machine tutor.
#
# **Prompt:**
#
# ```
# Explain the concept of curse of dimensionality in machine learning
#
# ```
# * [Bard Tutor Response](https://chat.openai.com/share/b9a5d6f8-e5ed-448c-b426-219801daf988)

# %% [markdown]
# ### **1.2.6 Building a Neural Network with Keras Library**
#
# [Keras](https://keras.io/) is an open-source library that provides a
# Python interface for building artificial neural networks.
#
# Let's use Keras library to construct a simple feedforward neural network model, consisting of three layers.

# %%
#remove any potential warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#Dependencies
import keras  # Importing the Keras library
from keras.models import Sequential  # Importing the Sequential model class from Keras
from keras.layers import Dense  # Importing the Dense layer class from Keras

# Neural network
model = Sequential()  # Initializing a sequential neural network model
model.add(Dense(16, input_dim=20, activation='relu'))  # Adding a dense layer with 16 neurons, input dimension of 20, and ReLU activation
model.add(Dense(12, activation='relu'))  # Adding another dense layer with 12 neurons and ReLU activation
model.add(Dense(4, activation='softmax'))  # Adding the output layer with 4 neurons and softmax activation

# %% [markdown]
# **Model Description**
#
# * **Sequential:** specifies to keras that we are creating model sequentially and the output of each layer we add is input to the next layer we specify.
#
# * **model.add:** is used to add a layer to our neural network
#
# * **Dense:** is used to specify the fully connected layer.
#
# The arguments of Dense are output dimension which is 16 in the first case, input dimension which is 20 for input dimension and the activation function to be used which is **relu** in this case.
#
# The second layer is similar, we dont need to specify input dimension as we have defined the model to be sequential so keras will automatically consider input dimension to be same as the output of last layer i.e 16.
#
# In the third layer(output layer) the output dimension is 4(number of classes).
#
# Now as we have discussed earlier, the output layer takes different activation functions and for the case of multiclass classification, it is **softmax**.
#
# Let us now compiled the model we just built.

# %%
# Compiling the model by specifying the loss function, optimizer, and metrics to monitor
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# Here loss is categorical_crossentropy loss. Categorical_crossentropy specifies that we have multiple classes.
#
# The optimizer is **Adam**. Metrics is used to specify the way we want to judge the performance of our neural network. Here we have specified it to accuracy.
#
# After these steps you are ready train your models.

# %% [markdown]
# # **2 Image Classification with ResNet50**

# %% [markdown]
# ## **2.1 Application Summary**
#
# With the escalating crisis of environmental pollution reaching unprecedented levels in recent decades, it is imperative to develop strategies for mitigation. One key challenge is the management and categorization of waste materials, a major contributor to environmental degradation.
#
# **Objective:**
# The goal of this project is to create an image-based classifier that can accurately identify different types of trash found in various environments. This will provide critical data for understanding the types of materials that are most responsible for pollution, and may also highlight specific areas where certain kinds of waste are more prevalent.
#
# Before we dive into the training (or fine-tuning) ResNet50 model architecture for classification, let's understand the concept of Transfer Learning, which is the foundation for which ResNet50 and other existing deep learning models are usually implemented.

# %% [markdown]
# ### 💡 **Transfer Learning**
#
# **What is Transfer Learning?**
# Transfer learning is a technique in machine learning where a model developed for a task is reused as the starting point for a model on a second task. This allows the second model to learn faster and achieve better performance because it can leverage the knowledge gained from the first task.
#
# **Why is it used?**
# Transfer learning is used because it can save a lot of time and resources compared to training a model from scratch. Additionally, it can be used when there is limited data available for the second task, making it easier to train a good model.
#
# **When should we use it?**
# Transfer learning should be used when the second task is related to the first task in some way. For example, if you have a model that has been trained to recognize objects in images and you want to train a model to recognize objects in videos, you can use the image recognition model as a starting point for the video recognition model.
#
# **Transfer Learning approaches**
# There are several approaches to transfer learning, such as fine-tuning, feature extraction, and multi-task learning. Fine-tuning involves training a pre-trained model on the new task by adjusting the weights of the model. Feature extraction involves using the features learned by the pre-trained model and training a new classifier on top of it. Multi-task learning involves training a model on multiple tasks simultaneously, which can lead to better performance on both tasks.
#
# **References:**
# - [Seldon](https://www.seldon.io/transfer-learning#:~:text=Transfer%20learning%20is%20generally%20used,categorisation%20or%20natural%20language%20processing)
# - [V7Labs](https://www.v7labs.com/blog/transfer-learning-guide)

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# > Copy and paste the prompt above in your [ChatGPT](https://chat.openai.com/) interface to see the response of ChatGPT machine tutor.
#
# **Prompt:**
#
# ```
# Explain the concept of Transfer Learning especially within the domain of deep learning.
#
# ```
#
# * [Bard Tutor Response](https://g.co/bard/share/d6b3e78f83e1)

# %% [markdown]
# ## **2.2 Introducing Dataset**
#
# | Related to | Related to | Related to | Related to |
# |------------|------------|------------|------------|
# | ![sdg](https://upload.wikimedia.org/wikipedia/commons/c/c4/Sustainable_Development_Goal_3.png)   | ![sdg](https://upload.wikimedia.org/wikipedia/commons/d/d9/Sustainable_Development_Goal_12.png)   | ![sdg](https://upload.wikimedia.org/wikipedia/commons/7/70/Sustainable_Development_Goal_13.png)   | ![sdg](https://upload.wikimedia.org/wikipedia/commons/1/18/Sustainable_Development_Goal_15.png)   |
#
# **Garbage Classification Data**
#
# The Garbage Classification Dataset contains 6 classifications: cardboard (393), glass (491), metal (400), paper(584), plastic (472) and trash(127).
#
# Example pictures for each category are shown below:
#
# 1. Cardboard
#
# ![sdg](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F1778553%2Faa165a00972f0e2382a51cae7495c186%2Fcardboard10.jpg?generation=1577153274006395&alt=media)
#
# 2. Glass
#
# ![sdg](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F1778553%2Fdef5c2805786a5b2f823b4b1115c5510%2Fglass105.jpg?generation=1577153372436433&alt=media)
#
# 3. Metal
#
# ![sdg](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F1778553%2Fe797ff9d99754a2d6c7100241f5f7092%2Fmetal101.jpg?generation=1577153407773402&alt=media)
#
# 4. Paper
#
# ![sdg](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F1778553%2Fdd8d6196a37658d28b8233ccb61677c0%2Fpaper1.jpg?generation=1577153456169200&alt=media)
#
#
# 5. Plastic
#
# ![sdg](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F1778553%2F7395afa02092b0761c66634ad5ae716c%2Fplastic1.jpg?generation=1577153479060787&alt=media)
#
# 6. Trash
#
# ![sdg](https://www.googleapis.com/download/storage/v1/b/kaggle-user-content/o/inbox%2F1778553%2F9d602f35b3a45c67912c443d0f5375b8%2Ftrash1.jpg?generation=1577153503621328&alt=media)

# %% [markdown]
# #### **2.2.1 Import Libraries and Load Dataset**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import required libraries
import re  # Regular expressions for string manipulations
import os  # Operating system functionalities like file manipulation
import numpy as np  # Numerical operations
import pandas as pd  # Dataframe operations

# TensorFlow for neural networks
import tensorflow as tf
from tensorflow.keras.applications import ResNet50  # ResNet50 model from Keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator  # Data generator for image augmentation

# Note: Depending on what you're going to do with these imports, more detailed comments may be added later on.

# %%
# Import necessary libraries
import re
import os
import pandas as pd

# Function to add class name prefix to the file path in the dataframe
def add_class_name_prefix(df, col_name):
    # Use regular expressions to find the first occurrence of a digit in the string,
    # then add a prefix based on everything before that digit, followed by the original string.
    df[col_name] = df[col_name].apply(lambda x: x[:re.search("\d", x).start()] + '/' + x)
    return df

# Function to map class ID to its corresponding label
def class_id_to_label(id):
    label_map = {1: 'glass', 2: 'paper', 3: 'cardboard', 4: 'plastic', 5: 'metal', 6: 'trash'}
    return label_map[id]

# Define directory and file paths


basedir = "/content/drive/MyDrive/SDG_AI_LAB_UNDP/DS4SDGS"

IMAGES_DIR = basedir + '/data/raw/garbage_classification/Garbage classification/'
train_file = basedir + '/data/raw/garbage_classification/one-indexed-files-notrash_train.txt'
val_file   = basedir + '/data/raw/garbage_classification/one-indexed-files-notrash_val.txt'
test_file  = basedir + '/data/raw/garbage_classification/one-indexed-files-notrash_test.txt'

# Read data files into Pandas DataFrames
df_train = pd.read_csv(train_file, sep=' ', header=None, names=['rel_path', 'label'])
df_valid = pd.read_csv(val_file,   sep=' ', header=None, names=['rel_path', 'label'])
df_test  = pd.read_csv(test_file,  sep=' ', header=None, names=['rel_path', 'label'])

# Apply the add_class_name_prefix function to modify 'rel_path' in each DataFrame
df_train = add_class_name_prefix(df_train, 'rel_path')
df_valid = add_class_name_prefix(df_valid, 'rel_path')
df_test  = add_class_name_prefix(df_test,  'rel_path')

# Convert the class IDs to their corresponding labels
df_train['label'] = df_train['label'].apply(class_id_to_label)
df_valid['label'] = df_valid['label'].apply(class_id_to_label)
df_test['label']  = df_test['label'].apply(class_id_to_label)

# Print the number of samples in each dataset
print(f'Found {len(df_train)} training, {len(df_valid)} validation and {len(df_test)} samples.')
# Out:
# Found 1768 training, 328 validation and 431 samples.

# %% [markdown]
# ## **2.3 Data Exploration**

# %%
df_train.head()
# Out:
#                      rel_path      label
# 0  cardboard/cardboard202.jpg  cardboard
# 1          paper/paper472.jpg      paper
# 2          paper/paper522.jpg      paper
# 3          glass/glass189.jpg      glass
# 4          glass/glass325.jpg      glass

# %% [markdown]
# #### **2.3.1 Extract images with ImageDataGenerator for Training**

# %%
# Importing ImageDataGenerator from TensorFlow's Keras API
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create an instance of the ImageDataGenerator class
datagen = ImageDataGenerator()

# Configure the data generator for the training dataset
datagen_train = datagen.flow_from_dataframe(
    dataframe=df_train,          # Dataframe containing the file paths and labels
    directory=IMAGES_DIR,        # Root directory where images are stored
    x_col='rel_path',            # Column in dataframe containing the file paths
    y_col='label',               # Column in dataframe containing the labels
    color_mode="rgb",            # Images will be converted to have 3 color channels (Red, Green, Blue)
    class_mode="categorical",    # Labels are in "categorical" format (useful for multi-class classification)
    batch_size=32,               # Number of samples to include in each batch (default is 32)
    shuffle=True,                # Shuffle the dataset randomly
    seed=7                       # Random seed for reproducibility
)

# Configure the data generator for the validation dataset
datagen_valid = datagen.flow_from_dataframe(
    dataframe=df_valid,          # Dataframe containing the file paths and labels
    directory=IMAGES_DIR,        # Root directory where images are stored
    x_col='rel_path',            # Column in dataframe containing the file paths
    y_col='label',               # Column in dataframe containing the labels
    color_mode="rgb",            # Images will be converted to have 3 color channels (Red, Green, Blue)
    class_mode="categorical",    # Labels are in "categorical" format (useful for multi-class classification)
    batch_size=32,               # Number of samples to include in each batch (default is 32)
    shuffle=True,                # Shuffle the dataset randomly
    seed=7                       # Random seed for reproducibility
)
# Out:
# Found 1768 validated image filenames belonging to 6 classes.
# Found 328 validated image filenames belonging to 6 classes.

# %% [markdown]
# ## **2.4 Model Training**

# %% [markdown]
# **Model Explanation:**
#
# * We will be using **ResNet50** network
#
# ResNets make it possible to train ultra deep neural networks. It has a network that can contain hundreds or thousands of layers and still achieve great performance.
#
# Our model architecture has the following properties:
#
# * Activation function as **relu** in hidden layer
# * Activation function as **softmax** as the output layer
# * Optimizer as **adam**
# * Loss function as **adam**
# * Metric as **categorical accuracy**

# %%
# Importing TensorFlow
import tensorflow as tf
from tensorflow.keras.applications import ResNet50

# Function to build the model
def build_model(num_classes):
    # Load the ResNet50 architecture with pretrained weights from ImageNet but without the top (final fully connected) layers
    base_model = ResNet50(weights='imagenet', include_top=False)

    # Get the output tensor of the base model
    x = base_model.output

    # Add a Global Average Pooling 2D layer to reduce the spatial dimensions of the output volume
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    # Add a fully-connected layer with 1024 hidden units and ReLU activation
    x = tf.keras.layers.Dense(1024, activation='relu')(x)

    # Add a final fully-connected layer with softmax activation for class probabilities
    predictions = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    # Configure the inputs and outputs and compile the model
    model = tf.keras.Model(inputs=base_model.input, outputs=predictions)

    # Freezing the layers of the base model (ResNet50)
    for layer in base_model.layers:
        layer.trainable = False

    return model

# Build the model with 6 output classes
net = build_model(num_classes=6)

# Compile the model with Adam optimizer, categorical cross-entropy loss and categorical accuracy as the metric
net.compile(optimizer='Adam',
            loss='categorical_crossentropy',
            metrics=[tf.keras.metrics.categorical_accuracy])

# Display the architecture of the model
net.summary()
# Out:
# ...
# 94765736/94765736 [==============================] - 0s 0us/step
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv1_pad (ZeroPadding2D)   (None, None, None, 3)        0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, None, None, 64)       9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, None, None, 64)       256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, None, None, 64)       0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, None, None, 64)       0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, None, None, 64)       0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, None, None, 64)       4160      ['pool1_pool[0][0]']
#  D)
#
# ...

# %%
history = net.fit(datagen_train,
    #generator=datagen_train,
    validation_data=datagen_valid,
    epochs=20,
    validation_freq=1)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 689s 12s/step - loss: 1.2195 - categorical_accuracy: 0.6725 - val_loss: 0.4599 - val_categorical_accuracy: 0.8171
# Epoch 2/20
# 56/56 [==============================] - 10s 174ms/step - loss: 0.3837 - categorical_accuracy: 0.8739 - val_loss: 0.3586 - val_categorical_accuracy: 0.8780
# Epoch 3/20
# 56/56 [==============================] - 10s 185ms/step - loss: 0.2389 - categorical_accuracy: 0.9157 - val_loss: 0.3482 - val_categorical_accuracy: 0.8902
# Epoch 4/20
# 56/56 [==============================] - 9s 163ms/step - loss: 0.1594 - categorical_accuracy: 0.9502 - val_loss: 0.3163 - val_categorical_accuracy: 0.8933
# Epoch 5/20
# 56/56 [==============================] - 11s 197ms/step - loss: 0.0897 - categorical_accuracy: 0.9768 - val_loss: 0.3070 - val_categorical_accuracy: 0.8933
# Epoch 6/20
# ...

# %%
# Import TensorFlow
import tensorflow as tf

# Create a ModelCheckpoint callback
# This callback saves the model at the filepath specified whenever 'val_accuracy' improves
# Reference: https://keras.io/api/callbacks/model_checkpoint/
checkpoint = tf.keras.callbacks.ModelCheckpoint(
    basedir + "/data/raw/garbage_classification/resnet50_model.h5",  # Filepath where the model will be saved
    monitor="val_accuracy",                              # Metric to monitor during training
    save_best_only=True,                                 # Only save the model that has the best 'val_accuracy'
    mode="auto",                                         # Mode set to 'auto', which means it would figure out when to save the model based on the monitored metric (val_accuracy in this case)
    verbose=1                                            # Logs the checkpoints being saved during training
)

# %%
# Callback that streams epoch results to a CSV file -- Reference: https://keras.io/api/callbacks/csv_logger/
log = tf.keras.callbacks.CSVLogger(basedir + '/data/raw/garbage_classification/resnet50_model.txt')

# %% [markdown]
# * We will be using **early stopping** to avoid overfitting
# * Monitoring the **validation loss**
# * **Epoch** number as 20(this parameter can be fine tuned after reviewing the outputs)

# %%
# Import TensorFlow
import tensorflow as tf

# Create an EarlyStopping callback
# This stops the training if 'val_loss' does not improve after 5 epochs
early_stop = tf.keras.callbacks.EarlyStopping(
    monitor='val_loss',            # Metric to monitor during training
    patience=5,                    # Number of epochs with no improvement to wait before stopping the training
    verbose=1,                     # Print messages for stopping
    restore_best_weights=True      # Restore model weights from the epoch with the best value of the monitored metric
)

# Training the model
history = net.fit(
    datagen_train,                 # Training data generator
    validation_data=datagen_valid, # Validation data generator
    epochs=20,                     # Number of epochs to train for
    validation_freq=1,             # Frequency (in epochs) at which to compute validation metrics
    callbacks=[early_stop, checkpoint, log] # List of callbacks to apply during training
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - ETA: 0s - loss: 0.0153 - categorical_accuracy: 0.9960
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 56/56 [==============================] - 9s 162ms/step - loss: 0.0153 - categorical_accuracy: 0.9960 - val_loss: 0.3392 - val_categorical_accuracy: 0.9024
# Epoch 2/20
# 56/56 [==============================] - ETA: 0s - loss: 0.0071 - categorical_accuracy: 0.9989
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# 56/56 [==============================] - 9s 158ms/step - loss: 0.0071 - categorical_accuracy: 0.9989 - val_loss: 0.3461 - val_categorical_accuracy: 0.8994
# Epoch 3/20
# 56/56 [==============================] - ETA: 0s - loss: 0.0072 - categorical_accuracy: 0.9983
# WARNING:tensorflow:Can save best model only with val_accuracy available, skipping.
# ...

# %%
# Import Matplotlib library for plotting
import matplotlib.pyplot as plt

# Create a 1x2 grid of subplots. The figure size is set as (20, 4)
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(20, 4))

# Plot the training loss on the first subplot
axs[0].plot(history.history['loss'], label='loss')

# Plot the validation loss on the first subplot
axs[0].plot(history.history['val_loss'], label='val_loss')

# Plot the training accuracy on the second subplot
axs[1].plot(history.history['categorical_accuracy'], label='acc')

# Plot the validation accuracy on the second subplot
axs[1].plot(history.history['val_categorical_accuracy'], label='val_acc')

# Add a legend to identify the lines in both subplots
plt.legend()

# Display the plots
plt.show()

# %%
# Remove comments to load saved model when needed!

#from tensorflow.keras.models import load_model

#net = load_model(basedir + "/data/raw/garbage_classification/resnet50_model.h5")

# %%
# Create a test data generator
test_generator = datagen.flow_from_dataframe(
    dataframe=df_test,              # Dataframe containing test samples
    directory=IMAGES_DIR,           # Root directory for loading images
    x_col='rel_path',               # Column in dataframe that contains the relative image paths
    y_col='label',                  # Column in dataframe that contains the labels
    color_mode="rgb",               # Color mode for images
    class_mode="categorical",       # Class mode for labels
    batch_size=1,                   # Batch size (1 means it will take one image at a time)
    shuffle=False,                  # Do not shuffle test data
    seed=7                          # Random seed for reproducibility
)

# Get filenames from the test generator
filenames = test_generator.filenames

# Get the number of samples in the test generator
nb_samples = len(filenames)

# Evaluate the model using the test data generator
# This will output the loss and any other metrics specified during model compilation, e.g., accuracy
net.evaluate(test_generator)
# Out:
# Found 431 validated image filenames belonging to 6 classes.
# 431/431 [==============================] - 80s 186ms/step - loss: 0.3989 - categorical_accuracy: 0.8886
# [0.398876816034317, 0.8886311054229736]

# %%
# Based on the Garbage Classification Dataset above, create dictionary which contains 6 classifications
class_dict = {0 : 'cardboard',
              1 : 'glass',
              2 : 'metal',
              3 : 'paper',
              4 : 'plastic',
              5 : 'trash'}

# %%
# Import the 'image' module from Keras' preprocessing package
from keras.preprocessing import image

# %%
new_image_list = []

# Load first image
new_image1= image.load_img(basedir + '/data/raw/bottle_plastic.jpg', target_size=(224, 224))
new_image_list.append(new_image1)
new_image1
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
# Load second image
new_image2= image.load_img(basedir + '/data/raw/bottle_plastic2.jpg', target_size=(224, 224))
new_image_list.append(new_image2)
new_image2
# Out:
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
# Loop over new images for prediction
for img in new_image_list:
    # Convert the image to a NumPy array
    transformed_image = image.img_to_array(img)

    # Add an extra dimension for batch size
    # Transforms (height, width, channels) to (1, height, width, channels)
    transformed_image = np.expand_dims(transformed_image, axis=0)

    # Make prediction using the pre-trained model
    pred = net.predict(transformed_image)

    # Retrieve the index of the class with maximum probability
    pred = np.argmax(pred)

    # Map the class index to the actual class name based on a dictionary
    pred_class = class_dict[pred]

    # Print the predicted class
    print(pred_class)
# Out:
# 1/1 [==============================] - 3s 3s/step
# glass
# 1/1 [==============================] - 0s 43ms/step
# plastic

# %%
# Create a sample dataframe with relative paths and labels
df_sample = pd.DataFrame({
    'rel_path': ['bootle_plastic.jpg', 'bottle_plastic2.jpg'],
    'label': ['bottle', 'bottle']
})

# Generate test data using ImageDataGenerator and the sample dataframe
test_generator = datagen.flow_from_dataframe(
    dataframe=df_sample,
    directory=basedir + '/data/raw/',
    x_col='rel_path',
    y_col='label',
    color_mode="rgb",
    class_mode="categorical",
    batch_size=1,
    shuffle=False,
    seed=7
)

# Get filenames from the test generator
filenames = test_generator.filenames

# Get the number of samples in the test generator
nb_samples = len(filenames)

# Evaluate the model using the test generator and get the evaluation metrics
# Note that `evaluate_generator` is deprecated in recent TensorFlow versions; you can use `evaluate` instead
a = net.evaluate_generator(test_generator, nb_samples)
# Out:
# Found 1 validated image filenames belonging to 1 classes.
# /usr/local/lib/python3.10/dist-packages/keras/src/preprocessing/image.py:1137: UserWarning: Found 1 invalid image filename(s) in x_col="rel_path". These filename(s) will be ignored.
#   warnings.warn(
# <ipython-input-27-86e260465cd6>:28: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   a = net.evaluate_generator(test_generator, nb_samples)

# %% [markdown]
# ## **2.5 Further Exploration and Hyperparameter Tuning**

# %% [markdown]
# Several parameters influence the ANN metric performance. Here we invite the reader to apply the ideas described in the bullet points to the code and see how they affect the model performance. Code snippets are added for guidance.
#
#
# **Optimiser:** Experiment with different optimisers, see Keras Documentation for a list of available options. Be aware that different optimisers have different parameters to tune as well.
#
# **Learning Rate:** Make sure to change the parameter called learning_rate for the optimiser. ANN weights are updated according to the learning rate. It heavily influences how fast or slow the network will learn. Remember that higher learning rates might make our model find a suboptimal solution. A balance between exploitation and exploration is desirable.

# %%
#Change Model Function and Call different Optimisers
def build_model(num_classes):
    base_model = ResNet50(weights='imagenet', include_top=False)
    x = base_model.output
    x = tf.keras.layers.GlobalAveragePooling2D()(x)
    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    predictions = tf.keras.layers.Dense(num_classes, activation='softmax')(x)

    model = tf.keras.Model(inputs=base_model.input, outputs=predictions)

    for layer in base_model.layers:
        layer.trainable = False
    return model

net = build_model(num_classes=6)

# Instantiate the optimizer with the desired learning rate
optimizer = tf.keras.optimizers.Adam(learning_rate=0.01)

net.compile(optimizer=optimizer,
            loss='categorical_crossentropy',
            metrics=[tf.keras.metrics.CategoricalAccuracy()])  # Note the change here as well

net.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_3 (InputLayer)        [(None, None, None, 3)]      0         []
#
#  conv1_pad (ZeroPadding2D)   (None, None, None, 3)        0         ['input_3[0][0]']
#
#  conv1_conv (Conv2D)         (None, None, None, 64)       9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, None, None, 64)       256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, None, None, 64)       0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, None, None, 64)       0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, None, None, 64)       0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, None, None, 64)       4160      ['pool1_pool[0][0]']
#  D)
#
# ...

# %% [markdown]
# * **Number of Epochs and Batch Size:** In the example, we use a callback called Early Stopping, so the model stops training as soon as there is no change in the validation set accuracy and the maximum number of Epochs (20) is not reached. In case the Early Stopping is not used, it is necessary to be attentive to this parameter. If we train for longer than necessary, the model will overfit and not perform well for unseen samples. Comment out the callbacks and note how the graphs will differ

# %%
history = net.fit(datagen_train,
    #generator=datagen_train,
    validation_data=datagen_valid,
    epochs=20,
    validation_freq=1)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 15s 198ms/step - loss: 5.9859 - categorical_accuracy: 0.6103 - val_loss: 0.6603 - val_categorical_accuracy: 0.7409
# Epoch 2/20
# 56/56 [==============================] - 10s 174ms/step - loss: 0.4360 - categorical_accuracy: 0.8433 - val_loss: 0.5433 - val_categorical_accuracy: 0.8049
# Epoch 3/20
# 56/56 [==============================] - 10s 175ms/step - loss: 0.3290 - categorical_accuracy: 0.8863 - val_loss: 0.4080 - val_categorical_accuracy: 0.8506
# Epoch 4/20
# 56/56 [==============================] - 10s 182ms/step - loss: 0.2154 - categorical_accuracy: 0.9219 - val_loss: 0.3779 - val_categorical_accuracy: 0.8902
# Epoch 5/20
# 56/56 [==============================] - 9s 167ms/step - loss: 0.1657 - categorical_accuracy: 0.9372 - val_loss: 0.3717 - val_categorical_accuracy: 0.8963
# Epoch 6/20
# ...

# %% [markdown]
# * **Callbacks:** Callbacks can be seen as functions built to help improve network performance or analysis. In this example, we used Early Stopping to reduce overfitting, as well as log and checkpoint to save our best model. Keras [documentation](https://keras.io/api/callbacks/) describes several Callbacks we can use and it also allows the creation of custom functions. Make sure to read and experiment with LearningRateScheduler, ReduceLRonPlateau and EarlyStopping as they are simple and effective ways to control and optimise your model.
#
# * **Pre-Trained Networks:** Currently we have several pre-trained architectures that have shown great performance in common image classification challenges. In this example we used ResNet50, however, other networks are also available in [Keras](https://keras.io/api/applications/) Applications. As a suggestion, try to use Xception instead of ResNet50. Xception is a more recent architecture compared to ResNet50 and presents top-performing results for the ImageNet dataset.

# %%
#Edit and Import Xception from keras.applications
from keras.applications import ResNet50, Xception

#Update the build_model function to call Xception instead of ResNet50

# %% [markdown]
# **Data Augmentation:** The ImageDataGenerator can also be fine-tuned to optimise the results. In this example, we used its default settings. The snippet below shows how to change the code to add rotation, rescaling and other parameters that create additional images slightly different from the original ones. For additional parameters and further guidance, see [documentation](https://www.tensorflow.org/api_docs/python/tf/keras/preprocessing/image/ImageDataGenerator).

# %%
datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=20,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   horizontal_flip=True,
                                   validation_split=0.2)

# %% [markdown]
# **Optimisation Libraries:** Manually tunning hyperparameters costs a tremendous amount of time. In addition, it would be humanly impossible to try all combinations to find the optimal values for all the hyperparameters. With that in mind, using an optimisation algorithm for this laborious task is worthwhile. Popular libraries with good tutorials available are [scikit-optimize](https://scikit-optimize.github.io/stable/) and [Optuna](https://optuna.org/)

# %% [markdown]
# What are the various hyperparameters that can be adjusted to optimize the performance of deep learning models?

# %% [markdown]
# # **3 Introduction to Transformers**

# %% [markdown]
# Transformers are a type of neural network architecture that were introduced in a 2017 paper by Google researchers, ["Attention is All You Need"](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf).
#
# They have since become popular in a wide range of natural language processing (NLP) tasks such as language translation, text summarization, and question answering.  It brought a significant shift in the way sequence-to-sequence tasks (like translation) were approached.
#
# Prior to Transformers, recurrent neural networks (RNNs) and their variants, like long short-term memory (LSTM) and gated recurrent units (GRU), were commonly used for such tasks. The Transformer model, however, does away with recurrence entirely and relies solely on attention mechanisms to draw global dependencies between input and output.
#
# To read more about the Transformer model architecture, click the link to the research paper ["Attention is All You Need"](https://proceedings.neurips.cc/paper_files/paper/2017/file/3f5ee243547dee91fbd053c1c4a845aa-Paper.pdf). Also consult  the Machine Tutor section below:
#
#
# There are several sources where you can find transformer-based deep learning models, including:
#
#
# 1. https://github.com/huggingface/transformers
# 2. https://www.tensorflow.org/hub/models
# 3. https://github.com/tensorflow/models/tree/main/official/nlp
# 4. https://pytorch.org/hub/
#
# If one's using [Huggingface](https://huggingface.co/), [TensorFlow](https://www.tensorflow.org/install), [Pytorch](https://pytorch.org/get-started/locally/) or Flax need to be downloaded to your local machine.
# Some Turkish models include: [BERTTurk](https://huggingface.co/savasy/bert-turkish-text-classification), [Turkish Translator](https://huggingface.co/Helsinki-NLP/opus-mt-tr-en) (which performs really good and a great tool if you want to use monolingual models)

# %% [markdown]
# #### 🤖 Machine Tutor Question
#
# **Prompt:**
#
# ```
# Explain the Transformer architecture in the domain of deep learning. What makes them different from other architectures?
#
# ```
#
# * [Bard Tutor Response](https://g.co/bard/share/6514853f7632)

# %%
from transformers import pipeline, AutoModelForSequenceClassification, AutoTokenizer

# %%
#Using transformers models are very easy but can be time consuming depending on your machine.
#Here is an example of how you might use the transformers library in Python to fine-tune a transformer-based model on a text classification task:

model = AutoModelForSequenceClassification.from_pretrained("bert-base-cased")
tokenizer = AutoTokenizer.from_pretrained("bert-base-cased")

classifier = pipeline('text-classification', model=model, tokenizer=tokenizer)

text = "This is an example of text classification."
print(classifier(text))

# %% [markdown]
# ## **3.1. BERT Language Model**

# %% [markdown]
# Pre-training refers to using model parameters of tasks that have been learned before to initialize the model parameters of new tasks. In this way, the old knowledge helps new models successfully perform new tasks from old experience instead of from scratch.
#
# BERT's pre-training task is called MLM, or Masked Language Model. In the input word sequence of this model, 15% of the words are randomly masked and the task is to predict what they are. What we see is that BERT can predict these words from both directions - not just left-to-right or right-to-left.
#
# There are significant benefits to using a pre-trained model. It reduces computation costs, and your carbon footprint, and allows you to use state-of-the-art models without having to train one from scratch. Transformers provides access to thousands of pre-trained models for a wide range of tasks. When you use a pre-trained model, you train it on a dataset specific to your task.
#
# This is known as fine-tuning, an incredibly powerful training technique. You can fine-tune a pretrained model with a deep learning framework such as TensorFlow with Keras, and PyTorch.

# %% [markdown]
# BERT was pre-trained using only an unlabeled, plain text corpus (namely the entirety of the English Wikipedia, and the Brown Corpus). It continues to learn unsupervised from the unlabeled text and improve even as its being used in practical applications (ie Google search). Its pre-training serves as a base layer of "knowledge" to build from. From there, BERT can adapt to the ever-growing body of searchable content and queries and be fine-tuned to a user's specifications. This process is known as transfer learning.

# %% [markdown]
# ### **3.1.1. Pre-training/ fine-tuning**

# %% [markdown]
# ![sdg](https://opendatascience.com/wp-content/uploads/2020/04/nlp7-640x300.png)

# %% [markdown]
# Pre-training refers to using model parameters of tasks that have been learned before to initialize the model parameters of new tasks. In this way, the old knowledge helps new models successfully perform new tasks from old experience instead of from scratch.
# BERT's pre-training task is called MLM, or Masked Language Model. In the input word sequence of this model, 15% of the words are randomly masked and the task is to predict what they are. What we see is that BERT can predict these words from both directions - not just left-to-right or right-to-left.
# There are significant benefits to using a pre-trained model. It reduces computation costs, and your carbon footprint, and allows you to use state-of-the-art models without having to train one from scratch. Transformers provides access to thousands of pre-trained models for a wide range of tasks. When you use a pre-trained model, you train it on a dataset specific to your task. This is known as fine-tuning, an incredibly powerful training technique. You can fine-tune a pre-trained model with a deep learning framework such as TensorFlow with Keras, and PyTorch.

# %% [markdown]
# #### **What is BERT used for?**

# %% [markdown]
# BERT is currently being used at Google to optimize the interpretation of user search queries. BERT excels at several functions that make this possible, including:
# Sequence-to-sequence-based language generation tasks such as:
# 1. Question Answering
# 2. Abstract summarization
# 3. Sentence prediction
# 4. Conversational response generation
# Natural language understanding tasks such as:
# 1. Polysemy and Coreference (words that sound or look the same but have different meanings) resolution
# 2. Word sense disambiguation
# 3. Natural language inference
# 4. Sentiment classification

# %% [markdown]
# ## **3.2 RoBERTa via HuggingFace**

# %% [markdown]
# #### **Installing required package**

# %%
# !pip install transformers

# %% [markdown]
# #### **Load Sentiment Analysis RoBERTA Model**

# %%
from transformers import pipeline
sentiment_analysis = pipeline("sentiment-analysis",model="siebert/sentiment-roberta-large-english")

# %% [markdown]
# #### **Sentiment Analysis Example 1**

# %%
print(sentiment_analysis("The Sustainable Development Goals are the blueprint to achieve a better and more sustainable future for all."))
# Out:
# [{'label': 'POSITIVE', 'score': 0.9986608028411865}]

# %% [markdown]
# #### **Sentiment Analysis Example 2**

# %%
print(sentiment_analysis("We don't have plan B because there is no planet B."))
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9991740584373474}]

# %% [markdown]
# #### **Sentiment Analysis Example 3**

# %%
print(sentiment_analysis("Such practices are often discursively linked to the Sustainable Development Goals. Some studies warn here of SDG washing by corporate actors, selective implementation of the goals, and the political risks linked to private investments in the context of continued shortage of public funding"))
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9971652626991272}]

# %% [markdown]
# References:
#
# * https://www.kaggle.com/mtszkw/garbage-keras-90-at-first-run-no-preprocessing/notebook
# * https://towardsdatascience.com/what-is-deep-learning-and-how-does-it-work-2ce44bb692ac
# * https://www.kaggle.com/asdasdasasdas/garbage-classification
# * https://towardsdatascience.com/curse-of-dimensionality-a-curse-to-machine-learning-c122ee33bfeb
# * https://www.mygreatlearning.com/blog/understanding-curse-of-dimensionality/
